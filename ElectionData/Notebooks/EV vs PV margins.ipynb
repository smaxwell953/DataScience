# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
diff = pd.read_csv('EV vs PV.csv')
diff.head()
# Out:
#    YEAR  EV MARGIN  PV MARGIN
# 0  1856     -20.27     -12.20
# 1  1860      55.45      10.13
# 2  1864      81.97      10.08
# 3  1868      45.58       5.33
# 4  1872      62.50      11.80

# %%
fig, ax = plt.subplots()
diff.plot(x = 'YEAR', y = 'EV MARGIN', ax = ax) 
diff.plot(x = 'YEAR', y = 'PV MARGIN', ax = ax, secondary_y = True)
# Out:
# <AxesSubplot:label='921fa9b9-deba-4bd4-af27-77d12005fca9'>
