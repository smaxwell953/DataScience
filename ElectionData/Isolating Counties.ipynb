# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
votes = pd.read_csv('./ElectionData/Michigan.csv', low_memory=False)
votes.head()
# Out:
#       State  Year     Office   County     D1#    R#  SD#  D2#  AS#  Nat.#  \
# 0  Michigan  1876  President   Alcona   162.0   155  NaN  NaN  0.0    NaN
# 1  Michigan  1876  President  Allegan  3169.0  4281  NaN  NaN  0.0    NaN
# 2  Michigan  1876  President   Alpena   635.0   629  NaN  NaN  0.0    NaN
# 3  Michigan  1876  President   Antrim   280.0   475  NaN  NaN  0.0    NaN
# 4  Michigan  1876  President   Baraga   232.0   218  NaN  NaN  0.0    NaN
#
#    ...  CON#  SD#.1  PU#  Tisch #  W/I7#  W/I8#  W/I9#  SqD#  CD#  T#
# 0  ...   NaN    NaN  NaN      NaN    NaN    NaN    NaN   NaN  NaN NaN
# 1  ...   NaN    NaN  NaN      NaN    NaN    NaN    NaN   NaN  NaN NaN
# 2  ...   NaN    NaN  NaN      NaN    NaN    NaN    NaN   NaN  NaN NaN
# 3  ...   NaN    NaN  NaN      NaN    NaN    NaN    NaN   NaN  NaN NaN
# 4  ...   NaN    NaN  NaN      NaN    NaN    NaN    NaN   NaN  NaN NaN
#
# [5 rows x 69 columns]

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10440 entries, 0 to 10439
# Data columns (total 69 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    10440 non-null  object
#  1   Year     10440 non-null  int64
#  2   Office   10440 non-null  object
#  3   County   10440 non-null  object
#  4   D1#      3136 non-null   float64
#  5   R#       10440 non-null  int64
#  6   SD#      166 non-null    float64
#  7   D2#      83 non-null     float64
#  8   AS#      76 non-null     float64
#  9   Nat.#    83 non-null     float64
#  10  Wor.#    332 non-null    float64
#  11  AF#      83 non-null     float64
#  12  Lib.#    83 non-null     float64
#  13  TC#      249 non-null    float64
#  14  NP#      83 non-null     float64
#  15  HR#      498 non-null    float64
#  16  Cit.#    83 non-null     float64
#  17  GB#      230 non-null    float64
#  18  FL#      166 non-null    float64
#  19  Proh.#   4222 non-null   float64
# ...

# %%
votes = votes.fillna(0)

# %%
votes['Year'] = pd.to_numeric(votes['Year'])

# %%
votes.loc[:,'Total Votes'] = (votes.sum(axis=1)) - votes['Year']

# %%
pres = votes[votes['Office'] == 'President']

# %%
pres = pres.drop('Office', axis = 1)

# %%
pres['Year'] = pd.to_numeric(pres['Year'])

# %%
pres['PCT_DEM'] = (round(pres['D#']/pres['Total Votes'],4))*100

# %%
pres['PCT_REP'] = (round(pres['R#']/pres['Total Votes'],4))*100

# %%
pres['RD_DIFF'] = pres['PCT_REP'] - pres['PCT_DEM']

# %%
pres_pct = pres[['State', 'Year', 'County', 'RD_DIFF']]

# %%
pres_pct_2000 = pres_pct[pres_pct['Year'] >= 2000]

# %%
counties = ['Alger', 'Baraga', 'Chippewa', 'Delta', 'Dickinson', 'Gogebic', 'Houghton', 'Iron', 'Keweenaw', 'Luce', \
            'Mackinac', 'Marquette', 'Menominee', 'Ontonagon', 'Schoolcraft']

# %%
for c in counties:
    print(pres_pct_2000[pres_pct_2000['County'] == c])
# Out:
#           State  Year County  RD_DIFF
# 2556   Michigan  2000  Alger    49.06
# 2639   Michigan  2004  Alger    48.65
# 2722   Michigan  2008  Alger    46.06
# 2805   Michigan  2012  Alger    50.45
# 2888   Michigan  2016  Alger    57.22
# 10358  Michigan  2020  Alger    58.70
#           State  Year  County  RD_DIFF
# 2561   Michigan  2000  Baraga    54.11
# 2644   Michigan  2004  Baraga    53.66
# 2727   Michigan  2008  Baraga    50.53
# 2810   Michigan  2012  Baraga    53.47
# 2893   Michigan  2016  Baraga    61.34
# 10363  Michigan  2020  Baraga    62.07
#           State  Year    County  RD_DIFF
# 2571   Michigan  2000  Chippewa    52.43
# 2654   Michigan  2004  Chippewa    55.33
# 2737   Michigan  2008  Chippewa    49.48
# 2820   Michigan  2012  Chippewa    52.86
# 2903   Michigan  2016  Chippewa    58.65
# 10373  Michigan  2020  Chippewa    60.44
#           State  Year County  RD_DIFF
# 2575   Michigan  2000  Delta    51.23
# 2658   Michigan  2004  Delta    50.32
# ...
